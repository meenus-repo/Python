# %%
Meenu
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Meenu
#
# NameError: name 'Meenu' is not defined

# %%
print ("Meenu")
# Out:
# Meenu

# %%
5+2
# Out:
# 7

# %%
20//5
# Out:
# 4

# %%
5**2
# Out:
# 25

# %%
10**3
# Out:
# 1000

# %%
5/2
# Out:
# 2.5

# %%
5%2
# Out:
# 1

# %%
9
# Out:
# 9

# %%
20>=200
# Out:
# False

# %%
85<=84
# Out:
# False

# %%
85<=85
# Out:
# True

# %%
85<=85 and 20>=200
# Out:
# False

# %%
20>=200 or 85<=85
# Out:
# True

# %%
5+4**2-33/7
# Out:
# 16.285714285714285
