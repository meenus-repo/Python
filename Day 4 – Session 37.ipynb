# %%
# Day 4 – Session 37

## Pandas: Filtering, Selecting, and Aggregation
#Topics covered:
#- Selecting data
#- Filtering with conditions
#- Aggregation (mean, sum, etc.)

# %%
### Selecting Data

# %%
print(df['Name'])
print(df[['Name', 'Age']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(df['Name'])
#       2 print(df[['Name', 'Age']])
#
# NameError: name 'df' is not defined

# %%
### Filtering with Conditions

# %%
print(df[df['Age'] > 28])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(df[df['Age'] > 28])
#
# NameError: name 'df' is not defined

# %%
### Aggregation
#- `mean()`
#- `sum()`
#- `max()`
#- `min()`

# %%
print("Mean Age:", df['Age'].mean())
print("Sum of Age:", df['Age'].sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print("Mean Age:", df['Age'].mean())
#       2 print("Sum of Age:", df['Age'].sum())
#
# NameError: name 'df' is not defined
